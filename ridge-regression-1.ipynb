# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import Ridge

# %%
df = pd.read_csv("/kaggle/input/refined-dataset/data.csv")
df
# Out:
#           Country  Year      Status  Life_Expectancy  Adult_Mortality  \
# 0     Afghanistan  2015  Developing             65.0            263.0
# 1     Afghanistan  2014  Developing             59.9            271.0
# 2     Afghanistan  2013  Developing             59.9            268.0
# 3     Afghanistan  2012  Developing             59.5            272.0
# 4     Afghanistan  2011  Developing             59.2            275.0
# ...           ...   ...         ...              ...              ...
# 2909     Zimbabwe  2004  Developing             44.3            723.0
# 2910     Zimbabwe  2003  Developing             44.5            715.0
# 2911     Zimbabwe  2002  Developing             44.8             73.0
# 2912     Zimbabwe  2001  Developing             45.3            686.0
# 2913     Zimbabwe  2000  Developing             46.0            665.0
#
#       Infant_Deaths  Alcohol  Percentage_Exp  HepatitisB   BMI  ...  \
# 0                62     0.01       71.279624        65.0  19.1  ...
# 1                64     0.01       73.523582        62.0  18.6  ...
# 2                66     0.01       73.219243        64.0  18.1  ...
# 3                69     0.01       78.184215        67.0  17.6  ...
# 4                71     0.01        7.097109        68.0  17.2  ...
# ...             ...      ...             ...         ...   ...  ...
# 2909             27     4.36        0.000000        68.0  27.1  ...
# 2910             26     4.06        0.000000         7.0  26.7  ...
# 2911             25     4.43        0.000000        73.0  26.3  ...
# 2912             25     1.72        0.000000        76.0  25.9  ...
# 2913             24     1.68        0.000000        79.0  25.5  ...
#
#       winsorized_Polio  winsorized_Tot_Exp  winsorized_Diphtheria  \
# 0                 47.0                8.16                   65.0
# 1                 58.0                8.18                   62.0
# 2                 62.0                8.13                   64.0
# 3                 67.0                8.52                   67.0
# 4                 68.0                7.87                   68.0
# ...                ...                 ...                    ...
# 2909              67.0                7.13                   65.0
# 2910              47.0                6.52                   68.0
# 2911              73.0                6.53                   71.0
# 2912              76.0                6.16                   75.0
# 2913              78.0                7.10                   78.0
#
#       winsorized_HIV  winsorized_GDP  winsorized_Population  \
# 0                0.1      584.259210             15799542.0
# 1                0.1      612.696514               327582.0
# 2                0.1      631.744976             15799542.0
# 3                0.1      669.959000              3696958.0
# 4                0.1       63.537231              2978599.0
# ...              ...             ...                    ...
# 2909             2.3      454.366654             12777511.0
# 2910             2.3      453.351155             12633897.0
# 2911             2.3       57.348340               125525.0
# 2912             2.3      548.587312             12366165.0
# 2913             2.3      547.358878             12222251.0
#
#       winsorized_thinness_1to19_years  winsorized_thinness_5to9_years  \
# 0                                14.2                            14.4
# 1                                14.2                            14.4
# 2                                14.2                            14.4
# 3                                14.2                            14.4
# 4                                14.2                            14.4
# ...                               ...                             ...
# 2909                              9.4                             9.4
# 2910                              9.8                             9.9
# 2911                              1.2                             1.3
# 2912                              1.6                             1.7
# 2913                             11.0                            11.2
#
#       winsorized_Income_Comp_Of_Resources  winsorized_Schooling
# 0                                   0.479                  10.1
# 1                                   0.476                  10.0
# 2                                   0.470                   9.9
# 3                                   0.463                   9.8
# 4                                   0.454                   9.5
# ...                                   ...                   ...
# 2909                                0.407                   9.2
# 2910                                0.418                   9.5
# 2911                                0.427                  10.0
# 2912                                0.427                   9.8
# 2913                                0.434                   9.8
#
# [2914 rows x 38 columns]

# %%
numerical_columns = [x for x in list(df.columns) if x.startswith("winsorized")]
numerical_columns
# Out:
# ['winsorized_Life_Expectancy',
#  'winsorized_Adult_Mortality',
#  'winsorized_Infant_Deaths',
#  'winsorized_Alcohol',
#  'winsorized_Percentage_Exp',
#  'winsorized_HepatitisB',
#  'winsorized_Under_Five_Deaths',
#  'winsorized_Polio',
#  'winsorized_Tot_Exp',
#  'winsorized_Diphtheria',
#  'winsorized_HIV',
#  'winsorized_GDP',
#  'winsorized_Population',
#  'winsorized_thinness_1to19_years',
#  'winsorized_thinness_5to9_years',
#  'winsorized_Income_Comp_Of_Resources',
#  'winsorized_Schooling']

# %%
numerical_columns = list(set(numerical_columns) - set("winsorized_Life_Expectancy"))
y = "winsorized_Life_Expectancy"
X_train = np.array(df[numerical_columns])
y_train = np.array(df[y])
prediction = np.array(df[numerical_columns].iloc[0].values)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_train,y_train ,
                                   random_state=1100, 
                                   test_size=0.25, 
                                   shuffle=True)

# %%
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import RandomForestRegressor
tscv = TimeSeriesSplit(n_splits=5)
i = 1
score = []
for tr_index, val_index in tscv.split(X_train):
    X_tr, X_val = X_train[tr_index], X_train[val_index]
    y_tr, y_val = y_train[tr_index], y_train[val_index]
    for al in np.linspace(10, 1000, 6):
        for mi in np.linspace(50, 100, 6):
            for tol in np.linspace(20, 40, 5):
                rfr = Ridge(
                    alpha=int(al),
                    max_iter=int(mi),
                    tol=tol)
                rfr.fit(X_tr, y_tr)
                score.append([i,
                              al, 
                              mi,
                              tol, 
                              rfr.score(X_val, y_val) ,  r2_score(rfr.predict(X_val ) , y_val)])
    i += 1

# %%
score[0]
max(score , key = lambda x : x[4])
# Out:
# [5, 10.0, 50.0, 20.0, 0.9999999733196002, 0.9999999733164933]

# %% [markdown]
# we get the highest accuracy for max_features = 1.1 , n_estimators = 60.0 , max_depth = 25.0 , min_samples_leaf = 30.0

# %%
model = Ridge(alpha=10.0,max_iter=int(50.0),tol=20.0)

# %%
max_score = 0
for tr_index, val_index in tscv.split(X_train):
    X_tr, X_val = X_train[tr_index], X_train[val_index]
    y_tr, y_val = y_train[tr_index], y_train[val_index]
    rfr = model
    rfr.fit(X_tr, y_tr)
    if rfr.score(X_val, y_val) > max_score:
        model = rfr

# %%
rfr.predict([prediction])
# Out:
# array([64.99886931])

# %%
import pickle
pickle.dump(rfr, open('model_baseline_Ridge.pkl','wb'))
